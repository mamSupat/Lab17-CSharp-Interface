// %% [markdown]
// # Lab 17 Exercise 2

// %% [markdown]
// ## call from interface references

// %% [markdown]
// 1.สร้าง console application project
// ```cmd
// dotnet new console --name Lab17_Ex02
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
// ```csharp
// IMovable [] animals = new Animal[3];
// animals[0] = new Dog();
// animals[1] = new Dog();
// animals[2] = new Dog();
//
// foreach (var animal in animals)
// {
//     animal.Move();
// }
//
// interface IMovable
// {
//     public void Move();
// }
//
// abstract class Animal : IMovable
// {
//     abstract public void Move();
// }
// class Dog : Animal
// {
//     public override void Move()
//     {
//         System.Console.WriteLine("Dog move by running on the ground");
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
// ```cmd
// dotnet build  Lab17_Ex02
// ```
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![03.png](attachment:03.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
// ```cmd
// dotnet run --project Lab17_Ex02
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![04.png](attachment:04.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// ในการทดลองนี้มีการใช้ interface IMovable เพื่อให้คลาส Dog ซึ่งสืบทอดจาก abstract class Animal สามารถใช้งานเมทอด Move() โดยกำหนดให้ Dog
//
// แสดงข้อความเมื่อเรียกใช้งานเมทอด
